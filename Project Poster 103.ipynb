# %% [markdown]
# # Caffeine Content in Drinks

# %% [markdown]
# ## Overview
# ### **Problem Question**: Do we misjudge the amount of caffeine in drinks we commonly consume?
#
# #### Data source
# * Data from Caffeine Infromer
#
# #### Why is it interesting?
# * Daily Consumption
# * University Life
# * Drink Choices
# * Health Issues

# %% [markdown]
# ## Design Choices
# * Graph Choice
# * Purpose of Program
# * What I would redo

# %% [markdown]
# ## Problem Solving
# * Comparison
# * Calculations
# * What it reveals
# #### Results

# %% [markdown]
# ![download%20%281%29.png](attachment:download%20%281%29.png)

# %% [markdown]
# ## Challenges
# * Matching Data
# * Unsorted data
# * Solutions - labeling/matching functions

# %% [markdown]
# ## Future Work
# * Use of problem solving and design skills
# * Health solutions
# * Informing
